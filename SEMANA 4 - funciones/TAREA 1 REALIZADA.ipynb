# %%
# Crear una lista que estará conformado por 7 elmentos que asumes seran las sublistas 
#con la cual sera representado cada caracter numerico que sera mostrado en el banner 

numero_0 = [[' ',' ','#','#','#',' ',' '],
            [' ','#',' ',' ',' ','#',' '],
            ['#',' ','#',' ',' ',' ','#'],
            ['#',' ',' ','#',' ',' ','#'],
            ['#',' ',' ',' ','#',' ','#'],
            [' ','#',' ',' ',' ','#',' '],
            [' ',' ','#','#','#',' ',' ']]

numero_1 = [[' ',' ',' ','#',' ',' ',' '],
            [' ',' ','#','#',' ',' ',' '],
            [' ','#',' ','#',' ',' ',' '],
            [' ',' ',' ','#',' ',' ',' '],
            [' ',' ',' ','#',' ',' ',' '],
            [' ',' ',' ','#',' ',' ',' '],
            [' ','#','#','#','#','#',' ']]

numero_2 = [[' ','#','#','#','#','#',' '],
            ['#',' ',' ',' ',' ',' ','#'],
            [' ',' ',' ',' ',' ',' ','#'],
            [' ','#','#','#','#','#',' '],
            ['#',' ',' ',' ',' ',' ',' '],
            ['#',' ',' ',' ',' ',' ',' '],
            ['#','#','#','#','#','#','#']]

numero_3 = [[' ','#','#','#','#','#',' '],
            ['#',' ',' ',' ',' ',' ','#'],
            [' ',' ',' ',' ',' ',' ','#'],
            [' ','#','#','#','#','#',' '],
            [' ',' ',' ',' ',' ',' ','#'],
            ['#',' ',' ',' ',' ',' ','#'],
            [' ','#','#','#','#','#',' ']]

numero_4 = [['#',' ',' ',' ',' ',' ',' '],
            ['#',' ',' ',' ',' ','#',' '],
            ['#',' ',' ',' ',' ','#',' '],
            ['#','#','#','#','#','#','#'],
            [' ',' ',' ',' ',' ','#',' '],
            [' ',' ',' ',' ',' ','#',' '],
            [' ',' ',' ',' ',' ','#',' ']]

numero_5 = [['#','#','#','#','#','#','#'],
            ['#',' ',' ',' ',' ',' ',' '],
            ['#',' ',' ',' ',' ',' ',' '],
            [' ','#','#','#','#','#',' '],
            [' ',' ',' ',' ',' ',' ','#'],
            ['#',' ',' ',' ',' ',' ','#'],
            [' ','#','#','#','#','#',' ']]

numero_6 = [[' ','#','#','#','#','#','#'],
            ['#',' ',' ',' ',' ',' ',' '],
            ['#',' ',' ',' ',' ',' ',' '],
            ['#','#','#','#','#','#',' '],
            ['#',' ',' ',' ',' ',' ','#'],
            ['#',' ',' ',' ',' ',' ','#'],
            [' ','#','#','#','#','#',' ']]

numero_7 = [['#','#','#','#','#','#','#'],
            ['#',' ',' ',' ',' ','#',' '],
            [' ',' ',' ',' ','#',' ',' '],
            [' ',' ',' ','#',' ',' ',' '],
            [' ',' ','#',' ',' ',' ',' '],
            [' ',' ','#',' ',' ',' ',' '],
            [' ',' ','#',' ',' ',' ',' '],]

numero_8 = [[' ','#','#','#','#','#',' '],
            ['#',' ',' ',' ',' ',' ','#'],
            ['#',' ',' ',' ',' ',' ','#'],
            [' ','#','#','#','#','#',' '],
            ['#',' ',' ',' ',' ',' ','#'],
            ['#',' ',' ',' ',' ',' ','#'],
            [' ','#','#','#','#','#',' ']]

numero_9 = [[' ','#','#','#','#','#',' '],
            ['#',' ',' ',' ',' ',' ','#'],
            ['#',' ',' ',' ',' ',' ','#'],
            [' ','#','#','#','#','#','#'],
            [' ',' ',' ',' ',' ',' ','#'],
            ['#',' ',' ',' ',' ',' ','#'],
            [' ','#','#','#','#','#',' ']]


# Crear una lista  con 7 elemntos que servira para seprar la hora del minuto y segundo
espacio = [["        "],
           ["        "],
           ["        "],
           ["        "],
           ["        "],
           ["        "],
           ["        "]]
    
def unir(n,numero):
    BAN=n
    for i in range(7):  #para i:0,1,2,3,4,5,6 al ser una una lista de 7 elementos
        for a in range (len(numero[i])):
            BAN[i].append(numero[i][a])
    
    return BAN

def u_esp(L,espacio):
    BAN=L
    for i in range(7):  #para i:0,1,2,3,4,5,6 al ser una una lista de 7 elementos
        for a in range (1):
            BAN[i].append(espacio[i][a])
    
    return BAN

    
def banner(hora):
    BANNER=espacio #BANNER es una lista principal que empezara almacenando una matriz de 2x7 con caracteres vacios
    
    for car in hora:
        if car == '0':
            BANNER=unir(BANNER,numero_0)
            
        elif car =='1':
            BANNER=unir(BANNER,numero_1)
            
        elif car =='2':
            BANNER=unir(BANNER,numero_2)
            
        elif car =='3':
            BANNER=unir(BANNER,numero_3)
            
        elif car =='4':
            BANNER=unir(BANNER,numero_4)
            
        elif car =='5':
            BANNER=unir(BANNER,numero_5)
            
        elif car =='6':
            BANNER=unir(BANNER,numero_6)
            
        elif car =='7':
            BANNER=unir(BANNER,numero_7)
            
        elif car =='8':
            BANNER=unir(BANNER,numero_8)
        
        elif car =='9':
            BANNER=unir(BANNER,numero_9)
        
        elif car ==':':
            BANNER=u_esp(BANNER,espacio)
                            
        
    return BANNER  

from time import strftime

time_str = strftime("%H:%M:%S")
print(time_str)


num=banner(time_str)
for i in range(0,len(num)):  #para i:0,1,2,3
        for j in range(0,len(num[i])): #para j:0,1,2,3,4,5,6
            print(num[i][j],end=" ")
        print()
# Out:
# 14:27:02
#                #       #                        # # # # #   # # # # # # #              # # #       # # # # #
#              # #       #         #            #           # #         #              #       #   #           #
#            #   #       #         #                        #         #              #   #       #             #
#                #       # # # # # # #            # # # # #         #                #     #     #   # # # # #
#                #                 #            #                 #                  #       #   # #
#                #                 #            #                 #                    #       #   #
#            # # # # #             #            # # # # # # #     #                      # # #     # # # # # # #

# %%
# Crear una lista que estará conformado por 7  sublistas 
#la cual sera representado cada caracter numerico  

numero_0 = [[' ',' ','#','#','#',' ',' ',' '],
            [' ','#',' ',' ',' ','#',' ',' '],
            ['#',' ','#',' ',' ',' ','#',' '],
            ['#',' ',' ','#',' ',' ','#',' '],
            ['#',' ',' ',' ','#',' ','#',' '],
            [' ','#',' ',' ',' ','#',' ',' '],
            [' ',' ','#','#','#',' ',' ',' ']]

numero_1 = [[' ',' ',' ','#',' ',' ',' ',' '],
            [' ',' ','#','#',' ',' ',' ',' '],
            [' ','#',' ','#',' ',' ',' ',' '],
            [' ',' ',' ','#',' ',' ',' ',' '],
            [' ',' ',' ','#',' ',' ',' ',' '],
            [' ',' ',' ','#',' ',' ',' ',' '],
            [' ','#','#','#','#','#',' ',' ']]

numero_2 = [[' ','#','#','#','#','#',' ',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#',' ',' '],
            ['#',' ',' ',' ',' ',' ',' ',' '],
            ['#',' ',' ',' ',' ',' ',' ',' '],
            ['#','#','#','#','#','#','#',' ']]

numero_3 = [[' ','#','#','#','#','#',' ',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#',' ',' '],
            [' ',' ',' ',' ',' ',' ','#',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#',' ',' ']]

numero_4 = [['#',' ',' ',' ',' ',' ',' ',' '],
            ['#',' ',' ',' ',' ','#',' ',' '],
            ['#',' ',' ',' ',' ','#',' ',' '],
            ['#','#','#','#','#','#','#',' '],
            [' ',' ',' ',' ',' ','#',' ',' '],
            [' ',' ',' ',' ',' ','#',' ',' '],
            [' ',' ',' ',' ',' ','#',' ',' ']]

numero_5 = [['#','#','#','#','#','#','#',' '],
            ['#',' ',' ',' ',' ',' ',' ',' '],
            ['#',' ',' ',' ',' ',' ',' ',' '],
            [' ','#','#','#','#','#',' ',' '],
            [' ',' ',' ',' ',' ',' ','#',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#',' ',' ']]

numero_6 = [[' ','#','#','#','#','#','#',' '],
            ['#',' ',' ',' ',' ',' ',' ',' '],
            ['#',' ',' ',' ',' ',' ',' ',' '],
            ['#','#','#','#','#','#',' ',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#',' ',' ']]

numero_7 = [['#','#','#','#','#','#','#',' '],
            ['#',' ',' ',' ',' ','#',' ',' '],
            [' ',' ',' ',' ','#',' ',' ',' '],
            [' ',' ',' ','#',' ',' ',' ',' '],
            [' ',' ','#',' ',' ',' ',' ',' '],
            [' ',' ','#',' ',' ',' ',' ',' '],
            [' ',' ','#',' ',' ',' ',' ',' '],]

numero_8 = [[' ','#','#','#','#','#',' ',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#',' ',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#',' ',' ']]

numero_9 = [[' ','#','#','#','#','#',' ',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#','#',' '],
            [' ',' ',' ',' ',' ',' ','#',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#',' ',' ']]



espacio = [[' ']*4]*7

#DEFINICIOINES A UTILIZAR EN EL PROGRAMA

def agregar(L_agregar,L_matriz): # en la lista "L_matriz" se agregran elementos de la lista "L_agregar"
    #print(L_agregar)
    print(len(L_agregar[0]))
    for i in range(7):  #para i:0,1,2,3,4,5,6 =>recorrera la lista de 7 elementos
        if L_agregar==espacio:
            for a in range (4): #para a:0,1,2,3 => recorrera la sublista de 4 elementos 
                L_matriz[i].append(L_agregar[i][a])
                
        else:
            for a in range (7): #para :0,1,2,3,4,5,6,7 =>recorrera la sublista de 8 elementos
                L_matriz[i].append(L_agregar[i][a]) 
    print()
    
    return L_matriz


    
def banner(hora):
    BANNER=[[]*4]*7 #se le asigna espaio al inicio, para que el baner este ubicada en el centro 
    
    for car in hora:
        if car == '0':
            BANNER=agregar(numero_0,BANNER)
            
        elif car =='1':
            BANNER=agregar(numero_1,BANNER)
            
        elif car =='2':
            BANNER=agregar(numero_2,BANNER)
            
        elif car =='3':
            BANNER=agregar(numero_3,BANNER)
            
        elif car =='4':
            BANNER=agregar(numero_4,BANNER)
            
        elif car =='5':
            BANNER=agregar(numero_5,BANNER)
            
        elif car =='6':
            BANNER=agregar(numero_6,BANNER)
            
        elif car =='7':
            BANNER=agregar(numero_7,BANNER)
            
        elif car =='8':
            BANNER=agregar(numero_8,BANNER)
        
        elif car =='9':
            BANNER=agregar(numero_9,BANNER)
        
        else:
            BANNER=agregar(espacio,BANNER)
                            
        
    return BANNER  


#capturar la hora actual y almacenar en una cadena
from time import strftime

time_str = strftime("%H:%M:%S")
#print(time_str)
print(time_str)

#imprimir la hora actual en forma de baner
panel=banner('1')
print(panel)
for i in range(len(panel)):  #para i:0,1,2,3,4,5,6 =># sub-listas
        for j in range(len(panel[i])): #para j:0,1,2..,len(panel[i])-1 =>posiciones de los elementos de la sub-lista
            print(panel[i][j],end=" ")
        print()
# Out:
# 11:41:22
# 8
#
# ...

# %%
# Crear una lista que estará conformado por 7  sublistas 
#la cual sera representado cada caracter numerico  

numero_0 = ([' ',' ','#','#','#',' ',' ',' '],
            [' ','#',' ',' ',' ','#',' ',' '],
            ['#',' ','#',' ',' ',' ','#',' '],
            ['#',' ',' ','#',' ',' ','#',' '],
            ['#',' ',' ',' ','#',' ','#',' '],
            [' ','#',' ',' ',' ','#',' ',' '],
            [' ',' ','#','#','#',' ',' ',' '])

numero_1 = ([' ',' ',' ','#',' ',' ',' ',' '],
            [' ',' ','#','#',' ',' ',' ',' '],
            [' ','#',' ','#',' ',' ',' ',' '],
            [' ',' ',' ','#',' ',' ',' ',' '],
            [' ',' ',' ','#',' ',' ',' ',' '],
            [' ',' ',' ','#',' ',' ',' ',' '],
            [' ','#','#','#','#','#',' ',' '])

numero_2 = ([' ','#','#','#','#','#',' ',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#',' ',' '],
            ['#',' ',' ',' ',' ',' ',' ',' '],
            ['#',' ',' ',' ',' ',' ',' ',' '],
            ['#','#','#','#','#','#','#',' '])

numero_3 = ([' ','#','#','#','#','#',' ',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#',' ',' '],
            [' ',' ',' ',' ',' ',' ','#',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#',' ',' '])

numero_4 = (['#',' ',' ',' ',' ',' ',' ',' '],
            ['#',' ',' ',' ',' ','#',' ',' '],
            ['#',' ',' ',' ',' ','#',' ',' '],
            ['#','#','#','#','#','#','#',' '],
            [' ',' ',' ',' ',' ','#',' ',' '],
            [' ',' ',' ',' ',' ','#',' ',' '],
            [' ',' ',' ',' ',' ','#',' ',' '])

numero_5 = (['#','#','#','#','#','#','#',' '],
            ['#',' ',' ',' ',' ',' ',' ',' '],
            ['#',' ',' ',' ',' ',' ',' ',' '],
            [' ','#','#','#','#','#',' ',' '],
            [' ',' ',' ',' ',' ',' ','#',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#',' ',' '])

numero_6 = ([' ','#','#','#','#','#','#',' '],
            ['#',' ',' ',' ',' ',' ',' ',' '],
            ['#',' ',' ',' ',' ',' ',' ',' '],
            ['#','#','#','#','#','#',' ',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#',' ',' '])

numero_7 = (['#','#','#','#','#','#','#',' '],
            ['#',' ',' ',' ',' ','#',' ',' '],
            [' ',' ',' ',' ','#',' ',' ',' '],
            [' ',' ',' ','#',' ',' ',' ',' '],
            [' ',' ','#',' ',' ',' ',' ',' '],
            [' ',' ','#',' ',' ',' ',' ',' '],
            [' ',' ','#',' ',' ',' ',' ',' '],)

numero_8 = ([' ','#','#','#','#','#',' ',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#',' ',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#',' ',' '])

numero_9 = ([' ','#','#','#','#','#',' ',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#','#',' '],
            [' ',' ',' ',' ',' ',' ','#',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#',' ',' '])



espacio = [[' ', ' ', ' ', ' '], [' ', ' ', ' ', ' '], [' ', ' ', ' ', ' '], [' ', ' ', ' ', ' '],
           [' ', ' ', ' ', ' '], [' ', ' ', ' ', ' '], [' ', ' ', ' ', ' ']]

#DEFINICIOINES A UTILIZAR EN EL PROGRAMA

def agregar(L_agregar,L_matriz): # en la lista "L_matriz" se agregran elementos de la lista "L_agregar"
    
    for i in range(7):  #para i:0,1,2,3,4,5,6 =>recorrera la lista de 7 elementos
        if L_agregar==espacio:
            for a in range (4): #para a:0,1,2,3 => recorrera la sublista de 4 elementos 
                L_matriz[i].append(L_agregar[i][a])
                
        else:
            for a in range (len(L_agregar[i])): #para :0,1,2,3,4,5,6,7 =>recorrera la sublista de 8 elementos
                L_matriz[i].append(L_agregar[i][a]) 
    
    return L_matriz


def banner(hora):
    BANNER=espacio#se le asigna espaio al inicio, para que el baner este ubicada en el centro 
    for car in hora:
        if car == '0':
            BANNER=agregar(numero_0,BANNER)
            
        elif car =='1':
            BANNER=agregar(numero_1,BANNER)
            
        elif car =='2':
            BANNER=agregar(numero_2,BANNER)
            
        elif car =='3':
            BANNER=agregar(numero_3,BANNER)
            
        elif car =='4':
            BANNER=agregar(numero_4,BANNER)
            
        elif car =='5':
            BANNER=agregar(numero_5,BANNER)
            
        elif car =='6':
            BANNER=agregar(numero_6,BANNER)
            
        elif car =='7':
            BANNER=agregar(numero_7,BANNER)
            
        elif car =='8':
            BANNER=agregar(numero_8,BANNER)
        
        elif car =='9':
            BANNER=agregar(numero_9,BANNER)
            
        else:
            BANNER=agregar(espacio,BANNER)
        
    return BANNER  



#capturar la hora actual y almacenar en una cadena
from time import strftime

time_str = strftime("%H:%M:%S")
print("Hora actaul: {}".format(time_str))

#imprimir la hora actual en forma de baner

panel=banner('11:45:66')
for i in range(len(panel)):  #para i:0,1,2,3,4,5,6 =># sub-listas
        for j in range(len(panel[i])): #para j:0,1,2..,len(panel[i])-1 =>posiciones de los elementos de la sub-lista
            print(panel[i][j],end=" ")
        print()
# Out:
# Hora actaul: 10:11:33
#               #               #                 #               # # # # # # #             # # # # # #     # # # # # #
#             # #             # #                 #         #     #                       #               #
#           #   #           #   #                 #         #     #                       #               #
#               #               #                 # # # # # # #     # # # # #             # # # # # #     # # # # # #
#               #               #                           #                 #           #           #   #           #
#               #               #                           #     #           #           #           #   #           #
#           # # # # #       # # # # #                       #       # # # # #               # # # # #       # # # # #

# %%
N0 = [['-','-','#','#','#','-','-','-'],
      ['-','#','-','-','-','#','-','-'],
      ['#','-','#','-','-','-','#','-'],
      ['#','-','-','#','-','-','#','-'],
      ['#','-','-','-','#','-','#','-'],
      ['-','#','-','-','-','#','-','-'],
      ['-','-','#','#','#','-','-','-']]

N1 = [['-','-','-','#','-','-','-','-'],
      ['-','-','#','#','-','-','-','-'],
      ['-','#','-','#','-','-','-','-'],
      ['-','-','-','#','-','-','-','-'],
      ['-','-','-','#','-','-','-','-'],
      ['-','-','-','#','-','-','-','-'],
      ['#','#','#','#','#','#','#','-']]

N2 = [['-','#','#','#','#','#','-','-'],
      ['#','-','-','-','-','-','#','-'],
      ['-','-','-','-','-','-','#','-'],
      ['-','#','#','#','#','#','-','-'],
      ['#','-','-','-','-','-','-','-'],
      ['#','-','-','-','-','-','-','-'],
      ['#','#','#','#','#','#','#','-']]

N3 = [['-','#','#','#','#','#','-','-'],
      ['#','-','-','-','-','-','#','-'],
      ['-','-','-','-','-','-','#','-'],
      ['-','#','#','#','#','#','-','-'],
      ['-','-','-','-','-','-','#','-'],
      ['#','-','-','-','-','-','#','-'],
      ['-','#','#','#','#','#','-','-']]

N4 = [['#','-','-','-','-','-','-','-'],
      ['#','-','-','-','-','#','-','-'],
      ['#','-','-','-','-','#','-','-'],
      ['#','#','#','#','#','#','#','-'],
      ['-','-','-','-','-','#','-','-'],
      ['-','-','-','-','-','#','-','-'],
      ['-','-','-','-','-','#','-','-']]

N5 = [['#','#','#','#','#','#','#','-'],
      ['#','-','-','-','-','-','-','-'],
      ['#','-','-','-','-','-','-','-'],
      ['-','#','#','#','#','#','-','-'],
      ['-','-','-','-','-','-','#','-'],
      ['#','-','-','-','-','-','#','-'],
      ['-','#','#','#','#','#','-','-']]

N6 = [['-','#','#','#','#','#','#','-'],
      ['#','-','-','-','-','-','-','-'],
      ['#','-','-','-','-','-','-','-'],
      ['#','#','#','#','#','#','-','-'],
      ['#','-','-','-','-','-','#','-'],
      ['#','-','-','-','-','-','#','-'],
      ['-','#','#','#','#','#','-','-']]

N7 = [['#','#','#','#','#','#','#','-'],
      ['#','-','-','-','-','#','-','-'],
      ['-','-','-','-','#','-','-','-'],
      ['-','-','-','#','-','-','-','-'],
      ['-','-','#','-','-','-','-','-'],
      ['-','-','#','-','-','-','-','-'],
      ['-','-','#','-','-','-','-','-']]

N8 = [['-','#','#','#','#','#','-','-'],
      ['#','-','-','-','-','-','#','-'],
      ['#','-','-','-','-','-','#','-'],
      ['-','#','#','#','#','#','-','-'],
      ['#','-','-','-','-','-','#','-'],
      ['#','-','-','-','-','-','#','-'],
      ['-','#','#','#','#','#','-','-']]

N9 = [['-','#','#','#','#','#','-','-'],
      ['#','-','-','-','-','-','#','-'],
      ['#','-','-','-','-','-','#','-'],
      ['-','#','#','#','#','#','#','-'],
      ['-','-','-','-','-','-','#','-'],
      ['#','-','-','-','-','-','#','-'],
      ['-','#','#','#','#','#','-','-']]

spa1=[['-'],
      ['-'],
      ['-'],
      ['-'],
      ['-'],
      ['-'],
      ['-']]

spa2=[['-','-']]*7

def add0(Nx0, Nx1): #funcion que permite añadir otras listas en la lista banner 
    for i in range (7):
        if Nx0 != spa1:
            for w in range (len(Nx0[i])):
                Nx1[i].append(Nx0[i][w]) #agrega a la lista banner el numero que se desee
            for v in range (1):
                Nx1[i].append(spa1[i][v]) #agrega 1 espacio mas para la separacion entre numeros
        else:
            for v in range (2):
                Nx1[i].append(spa2[i][v]) # agrega 2 espacios mas a y reemplaza a los dos puntos
    return Nx1
    
def banner(hora): #funcion que forma la lista completa
    BANNER = spa1 #20:15:07
    for val in hora:
        if   val == '0':
            BANNER = add0(N0, BANNER)
    
        elif val == '1':
            BANNER = add0(N1, BANNER)
        
        elif val == '2':
            BANNER = add0(N2, BANNER)
        
        elif val == '3':
            BANNER = add0(N3, BANNER)
        
        elif val == '4':
            BANNER = add0(N4, BANNER)
        
        elif val == '5':
            BANNER = add0(N5, BANNER)
        
        elif val == '6':
            BANNER = add0(N6, BANNER)
    
        elif val == '7':
            BANNER = add0(N7, BANNER)
    
        elif val == '8':
            BANNER = add0(N8, BANNER)
        
        elif val == '9':
            BANNER = add0(N9, BANNER)
        else:
            BANNER = add0(spa1, BANNER)     
    return BANNER

from time import strftime

time_str = strftime("%H:%M:%S")
print(time_str)
print()
       
panel=banner(time_str)
cont = 0
for x in range (len(panel)):
    for y in range(1, len(panel[x])-2):
        print(panel[x][y], end = '')
        cont=cont + 1  #contador que determina cuantas columnas tiene la matriz
    print()

print('\nEl Banner es de 7x{}'.format(int(cont/7)))
# Out:
# 10:53:07
#
# ---#-------###------#######---#####-------###----#######
# --##------#---#-----#--------#-----#-----#---#---#----#-
# -#-#-----#-#---#----#--------------#----#-#---#------#--
# ---#-----#--#--#-----#####----#####-----#--#--#-----#---
# ---#-----#---#-#----------#--------#----#---#-#----#----
# ---#------#---#-----#-----#--#-----#-----#---#-----#----
# #######----###-------#####----#####-------###------#----
#
# El Banner es de 7x56

# %%
espacio = [[' ']]
print(espacio)
# Out:
# [[' ', ' ', ' ', ' ', ' ', ' ', ' ']]
