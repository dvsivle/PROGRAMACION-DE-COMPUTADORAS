# %%
# Crear una lista con cada caracter numerico que sera mostrado en el banner 

numero_0 = [[' ',' ','#','#','#',' ',' '],
            [' ','#',' ',' ',' ','#',' '],
            ['#',' ','#',' ',' ',' ','#'],
            ['#',' ',' ','#',' ',' ','#'],
            ['#',' ',' ',' ','#',' ','#'],
            [' ','#',' ',' ',' ','#',' '],
            [' ',' ','#','#','#',' ',' ']]

numero_1 = [[' ',' ',' ','#',' ',' ',' '],
            [' ',' ','#','#',' ',' ',' '],
            [' ','#',' ','#',' ',' ',' '],
            [' ',' ',' ','#',' ',' ',' '],
            [' ',' ',' ','#',' ',' ',' '],
            [' ',' ',' ','#',' ',' ',' '],
            [' ','#','#','#','#','#',' ']]

numero_2 = [[' ','#','#','#','#','#',' '],
            ['#',' ',' ',' ',' ',' ','#'],
            [' ',' ',' ',' ',' ',' ','#'],
            [' ','#','#','#','#','#',' '],
            ['#',' ',' ',' ',' ',' ',' '],
            ['#',' ',' ',' ',' ',' ',' '],
            ['#','#','#','#','#','#','#']]

numero_3 = [[' ','#','#','#','#','#',' '],
            ['#',' ',' ',' ',' ',' ','#'],
            [' ',' ',' ',' ',' ',' ','#'],
            [' ','#','#','#','#','#',' '],
            [' ',' ',' ',' ',' ',' ','#'],
            ['#',' ',' ',' ',' ',' ','#'],
            [' ','#','#','#','#','#',' ']]

numero_4 = [['#',' ',' ',' ',' ',' ',' '],
            ['#',' ',' ',' ',' ','#',' '],
            ['#',' ',' ',' ',' ','#',' '],
            ['#','#','#','#','#','#','#'],
            [' ',' ',' ',' ',' ','#',' '],
            [' ',' ',' ',' ',' ','#',' '],
            [' ',' ',' ',' ',' ','#',' ']]

numero_5 = [['#','#','#','#','#','#','#'],
            ['#',' ',' ',' ',' ',' ',' '],
            ['#',' ',' ',' ',' ',' ',' '],
            [' ','#','#','#','#','#',' '],
            [' ',' ',' ',' ',' ',' ','#'],
            ['#',' ',' ',' ',' ',' ','#'],
            [' ','#','#','#','#','#',' ']]

numero_6 = [[' ','#','#','#','#','#','#'],
            ['#',' ',' ',' ',' ',' ',' '],
            ['#',' ',' ',' ',' ',' ',' '],
            ['#','#','#','#','#','#',' '],
            ['#',' ',' ',' ',' ',' ','#'],
            ['#',' ',' ',' ',' ',' ','#'],
            [' ','#','#','#','#','#',' ']]

numero_7 = [['#','#','#','#','#','#','#'],
            ['#',' ',' ',' ',' ','#',' '],
            [' ',' ',' ',' ','#',' ',' '],
            [' ',' ',' ','#',' ',' ',' '],
            [' ',' ','#',' ',' ',' ',' '],
            [' ',' ','#',' ',' ',' ',' '],
            [' ',' ','#',' ',' ',' ',' '],]

numero_8 = [[' ','#','#','#','#','#',' '],
            ['#',' ',' ',' ',' ',' ','#'],
            ['#',' ',' ',' ',' ',' ','#'],
            [' ','#','#','#','#','#',' '],
            ['#',' ',' ',' ',' ',' ','#'],
            ['#',' ',' ',' ',' ',' ','#'],
            [' ','#','#','#','#','#',' ']]

numero_9 = [[' ','#','#','#','#','#',' '],
            ['#',' ',' ',' ',' ',' ','#'],
            ['#',' ',' ',' ',' ',' ','#'],
            [' ','#','#','#','#','#','#'],
            [' ',' ',' ',' ',' ',' ','#'],
            ['#',' ',' ',' ',' ',' ','#'],
            [' ','#','#','#','#','#',' ']]



sep = [[' ',' '],
       [' ',' '],
       [' ',' '],
       [' ',' '],
       [' ',' '],
       [' ',' '],
       [' ',' ']]
    

num=numero_2   
    
for i in range(0,7):  #para i:1,3,5,7,.......2n-1
    for a in range (0,7):
        num[i].append(numero_2[i][a])
        
for i in range(0,7):  #para i:1,3,5,7,.......2n-1
    for a in range (0,2):
        num[i].append(sep[i][a])   #ESPACIOS
        
        
for i in range(0,7):  #para i:1,3,5,7,.......2n-1
    for a in range (0,7):
        num[i].append(numero_1[i][a])

        
for i in range(0,7):  #para i:1,3,5,7,.......2n-1
    for a in range (0,7):
        num[i].append(numero_7[i][a])

        
for i in range(0,7):  #para i:1,3,5,7,.......2n-1
    for a in range (0,2):
        num[i].append(sep[i][a])  #ESPACIOS
                
        
        
for i in range(0,7):  #para i:1,3,5,7,.......2n-1
    for a in range (0,7):
        num[i].append(numero_3[i][a])

for i in range(0,7):  #para i:1,3,5,7,.......2n-1
    for a in range (0,7):
        num[i].append(numero_9[i][a])
            
for i in range(0,len(num)):  #para i:0,1,2,3
        for j in range(0,len(num[i])): #para j:0,1,2,3,4,5,6
            print(num[i][j],end=" ")
        print()
# Out:
#   # # # # #     # # # # #             #       # # # # # # #       # # # # #     # # # # #
# #           # #           #         # #       #         #       #           # #           #
#             #             #       #   #               #                     # #           #
#   # # # # #     # # # # #             #             #             # # # # #     # # # # # #
# #             #                       #           #                         #             #
# #             #                       #           #             #           # #           #
# # # # # # # # # # # # # # #       # # # # #       #               # # # # #     # # # # #

# %%
numero_0 = [[' ',' ','#','#','#',' ',' '],
            [' ','#',' ',' ',' ','#',' '],
            ['#',' ','#',' ',' ',' ','#'],
            ['#',' ',' ','#',' ',' ','#'],
            ['#',' ',' ',' ','#',' ','#'],
            [' ','#',' ',' ',' ','#',' '],
            [' ',' ','#','#','#',' ',' ']]

numero_1 = [[' ',' ',' ','#',' ',' ',' '],
            [' ',' ','#','#',' ',' ',' '],
            [' ','#',' ','#',' ',' ',' '],
            [' ',' ',' ','#',' ',' ',' '],
            [' ',' ',' ','#',' ',' ',' '],
            [' ',' ',' ','#',' ',' ',' '],
            [' ','#','#','#','#','#',' ']]

numero_2 = [[' ','#','#','#','#','#',' '],
            ['#',' ',' ',' ',' ',' ','#'],
            [' ',' ',' ',' ',' ',' ','#'],
            [' ','#','#','#','#','#',' '],
            ['#',' ',' ',' ',' ',' ',' '],
            ['#',' ',' ',' ',' ',' ',' '],
            ['#','#','#','#','#','#','#']]

numero_3 = [[' ','#','#','#','#','#',' '],
            ['#',' ',' ',' ',' ',' ','#'],
            [' ',' ',' ',' ',' ',' ','#'],
            [' ','#','#','#','#','#',' '],
            [' ',' ',' ',' ',' ',' ','#'],
            ['#',' ',' ',' ',' ',' ','#'],
            [' ','#','#','#','#','#',' ']]

numero_4 = [['#',' ',' ',' ',' ',' ',' '],
            ['#',' ',' ',' ',' ','#',' '],
            ['#',' ',' ',' ',' ','#',' '],
            ['#','#','#','#','#','#','#'],
            [' ',' ',' ',' ',' ','#',' '],
            [' ',' ',' ',' ',' ','#',' '],
            [' ',' ',' ',' ',' ','#',' ']]

numero_5 = [['#','#','#','#','#','#','#'],
            ['#',' ',' ',' ',' ',' ',' '],
            ['#',' ',' ',' ',' ',' ',' '],
            [' ','#','#','#','#','#',' '],
            [' ',' ',' ',' ',' ',' ','#'],
            ['#',' ',' ',' ',' ',' ','#'],
            [' ','#','#','#','#','#',' ']]

numero_6 = [[' ','#','#','#','#','#','#'],
            ['#',' ',' ',' ',' ',' ',' '],
            ['#',' ',' ',' ',' ',' ',' '],
            ['#','#','#','#','#','#',' '],
            ['#',' ',' ',' ',' ',' ','#'],
            ['#',' ',' ',' ',' ',' ','#'],
            [' ','#','#','#','#','#',' ']]

numero_7 = [['#','#','#','#','#','#','#'],
            ['#',' ',' ',' ',' ','#',' '],
            [' ',' ',' ',' ','#',' ',' '],
            [' ',' ',' ','#',' ',' ',' '],
            [' ',' ','#',' ',' ',' ',' '],
            [' ',' ','#',' ',' ',' ',' '],
            [' ',' ','#',' ',' ',' ',' '],]

numero_8 = [[' ','#','#','#','#','#',' '],
            ['#',' ',' ',' ',' ',' ','#'],
            ['#',' ',' ',' ',' ',' ','#'],
            [' ','#','#','#','#','#',' '],
            ['#',' ',' ',' ',' ',' ','#'],
            ['#',' ',' ',' ',' ',' ','#'],
            [' ','#','#','#','#','#',' ']]

numero_9 = [[' ','#','#','#','#','#',' '],
            ['#',' ',' ',' ',' ',' ','#'],
            ['#',' ',' ',' ',' ',' ','#'],
            [' ','#','#','#','#','#','#'],
            [' ',' ',' ',' ',' ',' ','#'],
            ['#',' ',' ',' ',' ',' ','#'],
            [' ','#','#','#','#','#',' ']]



espacio = [[' ',' ',' ',' '],
           [' ',' ',' ',' '],
           [' ',' ',' ',' '],
           [' ',' ',' ',' '],
           [' ',' ',' ',' '],
           [' ',' ',' ',' '],
           [' ',' ',' ',' ']]
    
def unir(n,numero):
    BAN=n
    for i in range(7):  #para i:0,1,2,3,4,5,6 al ser una una lista de 7 elementos
        for a in range (7):
            BAN[i].append(numero[i][a])
    
    return BAN

def u_esp(L,espacio):
    BAN=L
    for i in range(7):  #para i:0,1,2,3,4,5,6 al ser una una lista de 7 elementos
        for a in range (4):
            BAN[i].append(espacio[i][a])
    
    return BAN

    
def banner(hora):
    BANNER=espacio #BANNER es una lista principal que empezara almacenando una matriz de 2x7 con caracteres vacios
    
    for car in hora:
        if car == '0':
            BANNER=unir(BANNER,numero_0)
            
        elif car =='1':
            BANNER=unir(BANNER,numero_1)
            
        elif car =='2':
            BANNER=unir(BANNER,numero_2)
            
        elif car =='3':
            BANNER=unir(BANNER,numero_3)
            
        elif car =='4':
            BANNER=unir(BANNER,numero_4)
            
        elif car =='5':
            BANNER=unir(BANNER,numero_5)
            
        elif car =='6':
            BANNER=unir(BANNER,numero_6)
            
        elif car =='7':
            BANNER=unir(BANNER,numero_7)
            
        elif car =='8':
            BANNER=unir(BANNER,numero_8)
        
        elif car =='9':
            BANNER=unir(BANNER,numero_9)
        
        elif car ==':':
            BANNER=u_esp(BANNER,espacio)
                            
        
    return BANNER  

from time import strftime

time_str = strftime("%H:%M:%S")
print(time_str)


num=banner(time_str)
for i in range(0,len(num)):  #para i:0,1,2,3
        for j in range(0,len(num[i])): #para j:0,1,2,3,4,5,6
            print(num[i][j],end=" ")
        print()
# Out:
# 12:32:37
#               #         # # # # #             # # # # #     # # # # #             # # # # #   # # # # # # #
#             # #       #           #         #           # #           #         #           # #         #
#           #   #                   #                     #             #                     #         #
#               #         # # # # #             # # # # #     # # # # #             # # # # #         #
#               #       #                                 # #                                 #     #
#               #       #                     #           # #                     #           #     #
#           # # # # #   # # # # # # #           # # # # #   # # # # # # #           # # # # #       #

# %%
from time import strftime

time_str = strftime("%H:%M:%S")
print(time_str)

print(len(time_str))
# Out:
# 12:32:03
# 8
