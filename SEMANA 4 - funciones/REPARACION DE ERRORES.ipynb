# %%
# Crear una lista que estará conformado por 7  sublistas 
#la cual sera representado cada caracter numerico  

numero_0 = ([' ',' ','#','#','#',' ',' ',' '],
            [' ','#',' ',' ',' ','#',' ',' '],
            ['#',' ','#',' ',' ',' ','#',' '],
            ['#',' ',' ','#',' ',' ','#',' '],
            ['#',' ',' ',' ','#',' ','#',' '],
            [' ','#',' ',' ',' ','#',' ',' '],
            [' ',' ','#','#','#',' ',' ',' '])

numero_1 = ([' ',' ',' ','#',' ',' ',' ',' '],
            [' ',' ','#','#',' ',' ',' ',' '],
            [' ','#',' ','#',' ',' ',' ',' '],
            [' ',' ',' ','#',' ',' ',' ',' '],
            [' ',' ',' ','#',' ',' ',' ',' '],
            [' ',' ',' ','#',' ',' ',' ',' '],
            [' ','#','#','#','#','#',' ',' '])

numero_2 = ([' ','#','#','#','#','#',' ',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#',' ',' '],
            ['#',' ',' ',' ',' ',' ',' ',' '],
            ['#',' ',' ',' ',' ',' ',' ',' '],
            ['#','#','#','#','#','#','#',' '])

numero_3 = ([' ','#','#','#','#','#',' ',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#',' ',' '],
            [' ',' ',' ',' ',' ',' ','#',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#',' ',' '])

numero_4 = (['#',' ',' ',' ',' ',' ',' ',' '],
            ['#',' ',' ',' ',' ','#',' ',' '],
            ['#',' ',' ',' ',' ','#',' ',' '],
            ['#','#','#','#','#','#','#',' '],
            [' ',' ',' ',' ',' ','#',' ',' '],
            [' ',' ',' ',' ',' ','#',' ',' '],
            [' ',' ',' ',' ',' ','#',' ',' '])

numero_5 = (['#','#','#','#','#','#','#',' '],
            ['#',' ',' ',' ',' ',' ',' ',' '],
            ['#',' ',' ',' ',' ',' ',' ',' '],
            [' ','#','#','#','#','#',' ',' '],
            [' ',' ',' ',' ',' ',' ','#',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#',' ',' '])

numero_6 = ([' ','#','#','#','#','#','#',' '],
            ['#',' ',' ',' ',' ',' ',' ',' '],
            ['#',' ',' ',' ',' ',' ',' ',' '],
            ['#','#','#','#','#','#',' ',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#',' ',' '])

numero_7 = (['#','#','#','#','#','#','#',' '],
            ['#',' ',' ',' ',' ','#',' ',' '],
            [' ',' ',' ',' ','#',' ',' ',' '],
            [' ',' ',' ','#',' ',' ',' ',' '],
            [' ',' ','#',' ',' ',' ',' ',' '],
            [' ',' ','#',' ',' ',' ',' ',' '],
            [' ',' ','#',' ',' ',' ',' ',' '],)

numero_8 = ([' ','#','#','#','#','#',' ',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#',' ',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#',' ',' '])

numero_9 = ([' ','#','#','#','#','#',' ',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#','#',' '],
            [' ',' ',' ',' ',' ',' ','#',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#',' ',' '])


espacio = [[' ']*4]*7 


#FUNCIOINES A UTILIZAR EN EL PROGRAMA

def agregar(L_agregar,BANNER):
    '''
     L_agregar y L_matriz reciben datos de dos listas, las cuales se encuantran pobladas con la misma cantidad de sublistas. 
     Los elemostos de las sublistas de "L_agregar" se agregaran en en las sublistas de "L_matriz", de la siguente manera:
     EJEMPLO:
         L_agregar=[['*','*'],['*','*']]
         L_matriz=[['-'],['-']]    
                 
         L_matriz=[['-','*','*'],['-','*','*']]  # retornará con los siguientes elementos
        Return L_matriz
    '''
   
    for i in range(len(BANNER)):   
        for a in range (len(L_agregar[i])): 
            BANNER[i].append(L_agregar[i][a]) 
            
    return BANNER


def banner(hora):
    BANNER=[[],[],[],[],[],[],[]] #se crea una lista principal con 7 sublistas vacias
    
    for car in hora:
        if car == '0':
            BANNER=agregar(numero_0,BANNER)
        
        elif car =='1':
            BANNER=agregar(numero_1,BANNER)
            
        elif car =='2':
            BANNER=agregar(numero_2,BANNER)
            
        elif car =='3':
            BANNER=agregar(numero_3,BANNER)
            
        elif car =='4':
            BANNER=agregar(numero_4,BANNER)
            
        elif car =='5':
            BANNER=agregar(numero_5,BANNER)
            
        elif car =='6':
            BANNER=agregar(numero_6,BANNER)
            
        elif car =='7':
            BANNER=agregar(numero_7,BANNER)
            
        elif car =='8':
            BANNER=agregar(numero_8,BANNER)
        
        elif car =='9':
            BANNER=agregar(numero_9,BANNER)
            
        else:
            BANNER=agregar(espacio,BANNER)
        
    return BANNER  



#capturar la hora actual y almacenar en una cadena
from time import strftime

hora_actual = strftime("%H:%M:%S")
BANNER=banner(hora_actual)

print('Hora actual:',hora_actual)
print('Dimensión del banner  {}x{}'.format(len(BANNER),len(BANNER[0])))
print()

for i in range(len(BANNER)):  #para i:0,1,2,3,4,5,6 =># sub-listas
    print('\t\t\t',end='')
    for j in range(len(BANNER[i])): #para j:0,1,2..,len(BANNER[i])-1 =>posiciones de los elementos de la sub-lista
        print(BANNER[i][j],end="")
    print()
# Out:
# Hora actual: 11:41:51
# Dimensión del banner  7x56
#
# 			   #       #        #          #        #######    #
# 			  ##      ##        #    #    ##        #         ##
# 			 # #     # #        #    #   # #        #        # #
# 			   #       #        #######    #         #####     #
# 			   #       #             #     #              #    #
# 			   #       #             #     #        #     #    #
# 			 #####   #####           #   #####       #####   #####

# %%
# Crear una lista que estará conformado por 7  sublistas 
#la cual sera representado cada caracter numerico  

numero_0 = ([' ',' ','#','#','#',' ',' ',' '],
            [' ','#',' ',' ',' ','#',' ',' '],
            ['#',' ','#',' ',' ',' ','#',' '],
            ['#',' ',' ','#',' ',' ','#',' '],
            ['#',' ',' ',' ','#',' ','#',' '],
            [' ','#',' ',' ',' ','#',' ',' '],
            [' ',' ','#','#','#',' ',' ',' '])

numero_1 = ([' ',' ',' ','#',' ',' ',' ',' '],
            [' ',' ','#','#',' ',' ',' ',' '],
            [' ','#',' ','#',' ',' ',' ',' '],
            [' ',' ',' ','#',' ',' ',' ',' '],
            [' ',' ',' ','#',' ',' ',' ',' '],
            [' ',' ',' ','#',' ',' ',' ',' '],
            [' ','#','#','#','#','#',' ',' '])

numero_2 = ([' ','#','#','#','#','#',' ',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#',' ',' '],
            ['#',' ',' ',' ',' ',' ',' ',' '],
            ['#',' ',' ',' ',' ',' ',' ',' '],
            ['#','#','#','#','#','#','#',' '])

numero_3 = ([' ','#','#','#','#','#',' ',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#',' ',' '],
            [' ',' ',' ',' ',' ',' ','#',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#',' ',' '])

numero_4 = (['#',' ',' ',' ',' ',' ',' ',' '],
            ['#',' ',' ',' ',' ','#',' ',' '],
            ['#',' ',' ',' ',' ','#',' ',' '],
            ['#','#','#','#','#','#','#',' '],
            [' ',' ',' ',' ',' ','#',' ',' '],
            [' ',' ',' ',' ',' ','#',' ',' '],
            [' ',' ',' ',' ',' ','#',' ',' '])

numero_5 = (['#','#','#','#','#','#','#',' '],
            ['#',' ',' ',' ',' ',' ',' ',' '],
            ['#',' ',' ',' ',' ',' ',' ',' '],
            [' ','#','#','#','#','#',' ',' '],
            [' ',' ',' ',' ',' ',' ','#',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#',' ',' '])

numero_6 = ([' ','#','#','#','#','#','#',' '],
            ['#',' ',' ',' ',' ',' ',' ',' '],
            ['#',' ',' ',' ',' ',' ',' ',' '],
            ['#','#','#','#','#','#',' ',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#',' ',' '])

numero_7 = (['#','#','#','#','#','#','#',' '],
            ['#',' ',' ',' ',' ','#',' ',' '],
            [' ',' ',' ',' ','#',' ',' ',' '],
            [' ',' ',' ','#',' ',' ',' ',' '],
            [' ',' ','#',' ',' ',' ',' ',' '],
            [' ',' ','#',' ',' ',' ',' ',' '],
            [' ',' ','#',' ',' ',' ',' ',' '],)

numero_8 = ([' ','#','#','#','#','#',' ',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#',' ',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#',' ',' '])

numero_9 = ([' ','#','#','#','#','#',' ',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#','#',' '],
            [' ',' ',' ',' ',' ',' ','#',' '],
            ['#',' ',' ',' ',' ',' ','#',' '],
            [' ','#','#','#','#','#',' ',' '])


espacio = [[' ']*4]*7 


#FUNCIOINES A UTILIZAR EN EL PROGRAMA

def agregar(L_agregar,BANNER):
    
    for i in range(len(BANNER)):   
        BANNER[i].extend(L_agregar[i]) # extend() agrega toda una lista al final
            
    return BANNER


def banner(hora):
    BANNER=[[],[],[],[],[],[],[]] #se crea una lista principal con 7 sublistas vacias
    
    for car in hora:
        if car == '0':
            BANNER=agregar(numero_0,BANNER)
        
        elif car =='1':
            BANNER=agregar(numero_1,BANNER)
            
        elif car =='2':
            BANNER=agregar(numero_2,BANNER)
            
        elif car =='3':
            BANNER=agregar(numero_3,BANNER)
            
        elif car =='4':
            BANNER=agregar(numero_4,BANNER)
            
        elif car =='5':
            BANNER=agregar(numero_5,BANNER)
            
        elif car =='6':
            BANNER=agregar(numero_6,BANNER)
            
        elif car =='7':
            BANNER=agregar(numero_7,BANNER)
            
        elif car =='8':
            BANNER=agregar(numero_8,BANNER)
        
        elif car =='9':
            BANNER=agregar(numero_9,BANNER)
            
        else:
            BANNER=agregar(espacio,BANNER)
        
    return BANNER  



#capturar la hora actual y almacenar en una cadena
from time import strftime

hora_actual = strftime("%H:%M:%S")
BANNER=banner(hora_actual)

print('Hora actual:',hora_actual)
print('Dimensión del banner  {}x{}'.format(len(BANNER),len(BANNER[0])))
print()

for i in range(len(BANNER)):  #para i:0,1,2,3,4,5,6 =># sub-listas
    print('\t\t\t',end='')
    for j in range(len(BANNER[i])): #para j:0,1,2..,len(BANNER[i])-1 =>posiciones de los elementos de la sub-lista
        print(BANNER[i][j],end="")
    print()
# Out:
# Hora actual: 12:05:13
# Dimensión del banner  7x56
#
# 			   #     #####        ###   #######        #     #####
# 			  ##    #     #      #   #  #             ##    #     #
# 			 # #          #     # #   # #            # #          #
# 			   #     #####      #  #  #  #####         #     #####
# 			   #    #           #   # #       #        #          #
# 			   #    #            #   #  #     #        #    #     #
# 			 #####  #######       ###    #####       #####   #####

# %%
l1=[[1,2],[3,4],[4,5]]
l2=[['a','b'],['c','d'],['e','f']]

for a in range(len(l1)):
    l1[a].extend(l2[a])
    
print(l1)
# Out:
# [[1, 2, 'a', 'b'], [3, 4, 'c', 'd'], [4, 5, 'e', 'f']]

# %%
l1=[1,2,3]
l2=[3,2,1]


l1=set(l1)
l2=set(l2)
if(l1==l2):
    print("Iguales")
else:
    print( "diferentes")
# Out:
# Iguales
