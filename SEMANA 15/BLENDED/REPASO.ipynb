# %%
def cambiar(texto):
    texto=texto.upper()
    num3=''
    for a in texto:
        if ('A'<=a and a<='C'):
            b='2'
        elif('D'<=a and a<='F'):
            b='3'
        elif('G'<=a and a<='I'):
            b='4'
        elif('J'<=a and a<='L'):
            b='5'
        elif('M'<=a and a<='O'):
            b='6'
        elif('P'<=a and a<='S'):
            b='7' 
        elif('T'<=a and a<='V'):
            b='8'
        else:
            b='9'
        num3=num3+b
    return num3
    
numero=input("Ingrese el número:")
numero=numero[:-4]+cambiar(numero[-4:])
print("Numero: ",numero)
# Out:
# Ingrese el número:0-800-dbas
# Numero:  0-800-3227

# %%
import os
def tres_veces(num):
    repite=-1
    cad=str(num)
    for a in cad:
        rep = cad.count(a)
        if rep==3:
            repite=int(a)
    return repite
tres_veces(162625287)

with open("numeros.txt",mode='r',encoding='utf-8') as archivo:

    listalineas=archivo.readlines()
    lista_num_r=[]
    for linea in listalineas:
        linea=linea.strip()
        lista_num_r.append(tres_veces(linea))
    
    print(lista_num_r)
# Out:
# [6, 4, -1, 2, -1, -1, -1, -1, 2, -1, -1, -1, -1, 2, 0, 1, -1, 0, -1, -1, 4, -1, -1, 4, 2, 9, 0, -1, 3, 2, -1, -1, -1, 3, 1, -1, 6, 9, 8, -1, 8, -1, 8, 1, 7, -1, 6, -1, -1, -1, 5, 5, 6, 1, 7, -1, 4, 3, 9, -1, 6, -1, 3, -1, 4, 5, -1, 8, 0, 4, -1, -1, 5, -1, -1, -1, 7, -1, -1, 0, -1, 4, 5, -1, 3, -1, 8, -1, 1, -1, -1, 5, 9, 0, -1, -1, -1, 5, 1, 2]

# %%
def reduceEspacios(cadena):
    lista_cad=cadena.split()
    cadena=' '.join(lista_cad)
    return cadena

with open("texto.txt",mode='r',encoding='utf-8') as lectura:
    listalineas=lectura.readlines()
    with open("texto_out.txt",mode='w') as escritura:
        for linea in listalineas:
            linea=linea.strip()
            linea=(reduceEspacios(linea))
            escritura.write(linea +'\n')

# %%
class Alumno:
    def __init__(self,Nombre='',codigo='',NC1=0,NC2=0,NC3=0,NC4=0,NC5=0):
        self.Nombre=Nombre
        self.codigo=codigo
        self.NC1=NC1
        self.NC2=NC2
        self.NC3=NC3
        self.NC4=NC4
        self.NC5=NC5
        
    @property
    def Nombre(self):
        return self.__Nombre
    @Nombre.setter
    def Nombre(self,newN):
        if (isinstance(newN,str)):
            self.__Nombre=newN
        else:
            print("Error, Nombre debe un tipo de dato str")
    @property
    def codigo(self):
        return self.__codigo
    @codigo.setter
    def codigo(self,codN):
        if (isinstance(codN,int) and len(str(codN))==9):
            self.__codigo=codN
        else:
            print("Error, Código debe ser un número entero de 9 dígitos")
    @property
    def NC1(self):
        return self.__NC1
    @NC1.setter
    def NC1(self,N_1):
        if (isinstance(N_1,int) or isinstance(N_1,float)):
            if(N_1>=0 and N_1<=20): #Rango de nota [0,20]
                self.__NC1=N_1
            else:
                print("Nota del curso 1 fuera de rango")
        else:
            print("Error, Nota del curso 1 es un tipo de dato incorrecto")
    @property
    def NC2(self):
        return self.__NC2
    @NC2.setter
    def NC2(self,N_2):
        if (isinstance(N_2,int) or isinstance(N_2,float)):
            if(N_2>=0 and N_2<=20):
                self.__NC2=N_2
            else:
                print("Nota del curso 2 fuera de rango")
        else:
            print("Error, Nota del curso 2 es un tipo de dato incorrecto")
    @property
    def NC3(self):
        return self.__NC3
    @NC3.setter
    def NC3(self,N_3):
        if (isinstance(N_3,int) or isinstance(N_3,float)):
            if(N_3>=0 and N_3<=20):
                self.__NC3=N_3
            else:
                print("Nota del curso 3 fuera de rango")
        else:
            print("Error, Nota del curso 3 es un tipo de dato incorrecto")
    @property
    def NC4(self):
        return self.__NC4
    @NC4.setter
    def NC4(self,N_4):
        if (isinstance(N_4,int) or isinstance(N_4,float)):
            if(N_4>=0 and N_4<=20):
                self.__NC4=N_4
            else:
                print("Nota del curso 4 fuera de rango")
        else:
            print("Error, Nota del curso 4 es un tipo de dato incorrecto")
    @property
    def NC5(self):
        return self.__NC5
    @NC5.setter
    def NC5(self,N_5):
        if (isinstance(N_5,int) or isinstance(N_5,float)):
            if(N_5>=0 and N_5<=20):
                self.__NC5=N_5
            else:
                print("Nota del curso 5 fuera de rango")
        else:
            print("Error, Nota del curso 5 es un tipo de dato incorrecto")
    
    def __str__(self):
        return "Nmbre:{}, Código:{}\nNota de los cursos:\n{}\n{}\n{}\n{}\n{}\n".format(self.Nombre,
                                                                                        self.codigo,
                                                                                        self.NC1,
                                                                                        self.NC2,
                                                                                        self.NC3,
                                                                                        self.NC4,
                                                                                        self.NC5)
    
    
    def promedio(self):
        notas=[self.NC1,self.NC2,self.NC3,self.NC4,self.NC5]
        return sum(notas)/5
    
    def estaAprobado(self):
        n=0
        notas=[self.NC1,self.NC2,self.NC3,self.NC4,self.NC5]
        for a in notas:
            if a>=12.5:
                n+=1
        if (n>=4):
            return True
        else:
            return False

# %%
# Codigo de prueba
a1 = Alumno("Francisco Riado", 201611090, 12.5, 16,9,11,10.5)

print("Nombre: ",a1.Nombre)
print("Código: ",a1.codigo)
print("curso 1 = {} curso 2 = {}, curso 3 = {}, curso 4 = {}, curso 5 = {}".format(a1.NC1,a1.NC2,a1.NC3,a1.NC4,a1.NC5))
print("Promedio: ",round(a1.promedio(),2))
if a1.estaAprobado():
    print("Estado: Aprobado en el ciclo")
else:
    print("Estado: Desaprobado en el ciclo")
# Out:
# Nombre:  Francisco Riado
# Código:  201611090
# curso 1 = 12.5 curso 2 = 16, curso 3 = 9, curso 4 = 11, curso 5 = 10.5
# Promedio:  11.8
# Estado: Desaprobado en el ciclo

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np


rango=np.linspace(0,1000,1000)
pasos= np.random.uniform(-1.0,1.0,1000)
suma=np.cumsum(pasos)
plt.axis([np.min(rango),np.max(rango),np.min(suma)-5,np.max(suma)+5])
plt.title("caminata aleatoria")
plt.ylabel("Distancia recorrida")
plt.xlabel("Número de pasos")
plt.plot(rango,suma)
plt.show()

# %%
from tkinter import*

root = Tk()
root.title("Calc de propinas")


f_num=0
def agregar(num):
    global operador
    operador=operador+str(num)
    input_text.set(operador) #VISUALIZAR LA OPERACION EN LA PANTALLA
def clear():
    global operador
    operador=("")
    input_text.set("0")
    
def operar(dato):
    global operador
    try:
        opera=str(eval(operador+dato))#REALIZAR LA OPERACIÓN PREVIAMENTE VISUALIZADA EN PANTALLA
    except:
        clear()
        opera=("ERROR")
    input_text.set(opera)#MUESTRA EL RESULTADO

input_text=StringVar()
operador=""
nx=40
ny=10
pantalla=Label(root, font=('arial',10,'bold'),textvariable=input_text,bd=20,anchor="e")
pantalla.grid(row=4,columnspan=4)

b_1=Button(root,text="1",padx=nx,pady=ny,command=lambda:agregar('1'))
b_2=Button(root,text="2",padx=nx,pady=ny,command=lambda:agregar('2'))
b_3=Button(root,text="3",padx=nx,pady=ny,command=lambda:agregar('3'))
b_4=Button(root,text="4",padx=nx,pady=ny,command=lambda:agregar('4'))
b_5=Button(root,text="5",padx=nx,pady=ny,command=lambda:agregar('5'))
b_6=Button(root,text="6",padx=nx,pady=ny,command=lambda:agregar('6'))
b_7=Button(root,text="7",padx=nx,pady=ny,command=lambda:agregar('7'))
b_8=Button(root,text="8",padx=nx,pady=ny,command=lambda:agregar('8'))
b_9=Button(root,text="9",padx=nx,pady=ny,command=lambda:agregar('9'))
b_0=Button(root,text="0",padx=nx*2+10,pady=ny,command=lambda:agregar('0'))
b_5por =Button(root,text="5%",padx=nx,pady=ny,command=lambda:operar('*5/100'))
b_10por=Button(root,text="10%",padx=nx,pady=ny,command=lambda:operar('*10/100'))
b_15por=Button(root,text="15%",padx=nx,pady=ny,command=lambda:operar('*15/100'))
b_20por=Button(root,text="20%",padx=nx,pady=ny,command=lambda:operar('*20/100'))
b_punto  =Button(root,text=".",padx=nx,pady=ny,command=lambda:agregar('.'))


b_1.grid(row=3, column=0)
b_2.grid(row=3, column=1)
b_3.grid(row=3, column=2)

b_4.grid(row=2, column=0)
b_5.grid(row=2, column=1)
b_6.grid(row=2, column=2)

b_7.grid(row=1, column=0)
b_8.grid(row=1, column=1)
b_9.grid(row=1, column=2)

b_0.grid(row=4, column=0, columnspan=2 )
b_punto.grid(row=4, column=2)

b_5por.grid( row=1, column=3)
b_10por.grid(row=2, column=3)
b_15por.grid(row=3, column=3)
b_20por.grid(row=4, column=3)

root.mainloop()

# %%
str(eval("2*100")
# Out:
# '200'

# %%
from tkinter import*

root =Tk()
root.title("Calc de propinas")
a=55
def agregar(num):
    global a
    global operador
    if a==0:
        operador=("")
        a=1
    operador=operador+str(num)
    input_text.set(operador) 
        
def operar(dato):
    global a
    global operador
    a=0
    try:
        opera=float(operador)*dato/100
        operador=opera
    except:
        operador=("")
        opera=("ERROR")
    input_text.set(opera)#MUESTRA EL RESULTADO
    
input_text=StringVar()
operador="0"
nx=40
ny=10

frame_1=Frame(root)
frame_1.pack(fill=X)
pantalla=Label(frame_1, font=('arial',20,'bold'),textvariable=input_text,width=23,anchor="e")
pantalla.pack()

frame_2=Frame(root)
frame_2.pack(fill=X)

b_1=Button(frame_2,text="1",padx=nx,pady=ny,command=lambda:agregar('1'))
b_2=Button(frame_2,text="2",padx=nx,pady=ny,command=lambda:agregar('2'))
b_3=Button(frame_2,text="3",padx=nx,pady=ny,command=lambda:agregar('3'))
b_4=Button(frame_2,text="4",padx=nx,pady=ny,command=lambda:agregar('4'))
b_5=Button(frame_2,text="5",padx=nx,pady=ny,command=lambda:agregar('5'))
b_6=Button(frame_2,text="6",padx=nx,pady=ny,command=lambda:agregar('6'))
b_7=Button(frame_2,text="7",padx=nx,pady=ny,command=lambda:agregar('7'))
b_8=Button(frame_2,text="8",padx=nx,pady=ny,command=lambda:agregar('8'))
b_9=Button(frame_2,text="9",padx=nx,pady=ny,command=lambda:agregar('9'))
b_0=Button(frame_2,text="0",padx=nx*2+10,pady=ny,command=lambda:agregar('0'))
b_5por =Button(frame_2,text="5%",padx=nx,pady=ny,command=lambda:operar(5),activebackground="gold")
b_10por=Button(frame_2,text="10%",padx=nx,pady=ny,command=lambda:operar(10),activebackground="gold")
b_15por=Button(frame_2,text="15%",padx=nx,pady=ny,command=lambda:operar(15),activebackground="gold")
b_20por=Button(frame_2,text="20%",padx=nx,pady=ny,command=lambda:operar(20),activebackground="gold")
b_punto  =Button(frame_2,text=".",padx=nx,pady=ny,command=lambda:agregar('.'))

b_1.grid(row=2, column=0)
b_2.grid(row=2, column=1)
b_3.grid(row=2, column=2)
b_4.grid(row=1, column=0)
b_5.grid(row=1, column=1)
b_6.grid(row=1, column=2)

b_7.grid(row=0, column=0)
b_8.grid(row=0, column=1)
b_9.grid(row=0, column=2)

b_0.grid(row=3, column=0, columnspan=2 )
b_punto.grid(row=3, column=2)

b_5por.grid( row=0, column=3)
b_10por.grid(row=1, column=3)
b_15por.grid(row=2, column=3)
b_20por.grid(row=3, column=3)
root.resizable(width=False, height=False)
root.mainloop()

# %% [markdown]
# ## from tkinter import *
#
# top = Tk()
# Lb = Listbox(top)
# Lb.insert(1, 'Python')
# Lb.insert(2, 'Java')
# Lb.insert(3, 'C++')
# Lb.insert(4, 'Any other')
# Lb.pack()
# top.mainloop()

# %%
from tkinter import*
import math
root =Tk()
root.title("Calc prestamo")

#variables
M = DoubleVar(value='0.00') # Monto mensual
r = DoubleVar(value='') #tasa de interes anual
y = DoubleVar(value='') #numero de años
P = DoubleVar(value='') #monto prestamo
A = DoubleVar(value='0.00') # Total anual

def calcular():
   
    r1=r.get()/100
    x1=(P.get()*(r1/12))
    x2=(1-math.pow(1+(r1/12),(-12*y.get())))
    l_4_2.config(text="{:.3f}".format(x1/x2))
    l_5_2.config(text="{:.3f}".format((x1/x2)*12))

frame1=Frame(root,padx=5, pady=2)
frame1.pack(fill=X)
frame2=Frame(root, padx=5, pady=2)
frame2.pack(fill=X)
frame3=Frame(root, padx=5, pady=2)
frame3.pack(fill=X)
frame4=Frame(root, padx=5, pady=2)
frame4.pack(fill=X)
frame5=Frame(root, padx=5, pady=2)
frame5.pack(fill=X)
frame6=Frame(root, padx=5, pady=2)
frame6.pack(fill=X)
L_1=Label(frame1, text='Tasa de interes anual',fon=("Arial", 12)).pack(side="left")
E_1=Entry(frame1,width=20, font=('currier', 12),textvariable=r,justify='right').pack(side="right")

L_2=Label(frame2, text='Numero de años',fon=("Arial", 12)).pack(side="left")
E_2=Entry(frame2,width=20, font=('currier', 12),textvariable=y,justify='right')
E_2.pack(side="right")

L_3=Label(frame3, text='Monto prestamo',fon=("Arial", 12)).pack(side="left")
E_3=Entry(frame3,width=20, font=('currier', 12),textvariable=P,justify='right').pack(side="right")

L_4_1=Label(frame4, text='Pago mensual',fon=("Arial", 12)).pack(side="left")
l_4_2=Label(frame4,text="0.00",fon=('currier', 12))
l_4_2.pack(side="right")

L_5_1=Label(frame5, text='Total anual',fon=("Arial", 12)).pack(side="left")
l_5_2=Label(frame5, text='0.00',fon=('currier', 12))
l_5_2.pack(side="right")
L_6=Button(frame6,text="Calcular pago",fon=("Arial", 12),command=calcular)
L_6.pack(side="right")

root.mainloop()

# %%
import numpy as np
import math


P = 100000
r = 3
y = 10


r1=r/100
x1=(P*(r1/(12)))
x2=(1-(1+r1/12)**(-12*y))

print("{:.3f}".format(x1/x2))
# Out:
# 965.607

# %%
def calcular():
   
    r1=r.get()/100
    x1=(P.get()*(r1/12))
    x2=(1-math.pow((r1/12),(-12*y.get())))
    l_4_2.config(text="{:.3f}".format(x1/x2))
   #A.set(an)2

# %%
from tkinter import*
root=Tk()
root.title('Calc Prestamo')

#variables:
R=DoubleVar()
Y=DoubleVar()
P=DoubleVar()

#funciones:
def calcula():
    mensual=(P.get()*(R.get()*0.01/2))/(1-(1+(R.get()*0.01/12)*(-12*Y.get())))
    salida1.config(text='{:.2f}'.format(mensual))
    salida2.config(text='{:.2f}'.format(mensual*120))


#creando frames:
frame1=Frame(root, padx=5, pady=5)
frame1.pack()
frame2=Frame(root, padx=5, pady=2)
frame2.pack(side=RIGHT)

#contenido de los frames:
label1=Label(frame1, text='Tasa de interes anual', font=('verdana 14'), width=17, anchor='w',
             padx=4, pady=4)
label2=Label(frame1, text='Numero de años', font=('verdana 14'), width=17, anchor='w',
            padx=4, pady=4)
label3=Label(frame1, text='Monton prestamo', font=('verdana 14'), width=17, anchor='w',
            padx=4, pady=4)
label4=Label(frame1, text='Pago mensual', font=('verdana 14'), width=17, anchor='w',
             padx=4, pady=4)
label5=Label(frame1, text='Total anual', font=('verdana 14'), width=17, anchor='w',
             padx=4, pady=4)

#entrdas:
entrada1=Entry(frame1, font=('verdana 14'), textvariable=R)#, anchor='e')
entrada2=Entry(frame1, font=('verdana 14'), textvariable=Y)#, anchor='e')
entrada3=Entry(frame1, font=('verdana 14'), textvariable=P)#, anchor='e')

#salidas:
salida1=Label(frame1, text='0.00', font=('verdana 14'), width=17, anchor='e')
salida2=Label(frame1, text='0.00', font=('verdana 14'), width=17, anchor='e')

#boton:
boton=Button(frame2, text='Calcular Pago', font=('verdana 14'),width=12,
            command=calcula)

#ubicaciones:
label1.grid(row=0, column=0, sticky=W+E)
label2.grid(row=1, column=0, sticky=W+E)
label3.grid(row=2, column=0, sticky=W+E)
label4.grid(row=3, column=0, sticky=W+E)
label5.grid(row=4, column=0, sticky=W+E)
salida1.grid(row=3, column=1, sticky=W+E)
salida2.grid(row=4, column=1, sticky=W+E)
entrada1.grid(row=0, column=1, sticky=W+E)
entrada2.grid(row=1, column=1, sticky=W+E)
entrada3.grid(row=2, column=1, sticky=W+E)
#boton.grid(row=0, column=1, sticky=W+E)
boton.pack()

root.resizable(width=False, height=False)
root.mainloop()

# %%
import os 

with open (os.getcwd()+'//'+'texto.txt',mode='r',encoding='utf-8') as archivoR:
    lineas=archivoR.readlines()
    with open (os.getcwd()+'//'+'texto_out.txt', mode='w') as archivoW:
        #lista1=lineas.split('\n')
        for i in lineas:
            aux=i.split()
            for v in aux:
                
                archivoW.write(v+' ')
            archivoW.write('\n')
